# %% [markdown]
# <a href="https://colab.research.google.com/github/quangteo301/thtoancaocap1/blob/main/chuong4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colap import drive
#drive.mount('/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt
fs = [1,2,4]
all_time = np.linspace(0,2,200)
t=all_time[:100]
for f in fs:
  y=np.sin(2*np.pi*f*t)
  plt.plot(t,y,label='{}Hz'.format(f))
plt.legend
from google.colab import drive
drive.mount('/drive')
plt.savefig('/drive/My Drive/toancc/basic.python.pdf')
plt.show()
# Out:
# Mounted at /drive

# %%
import numpy as np
import matplotlib.pyplot as plt
fs = [1,2,4]
all_time = np.linspace(0,2,200)
t=all_time[:100]
fig, ax = plt.subplots()
for f in fs:
  y=np.sin(2*np.pi*f*t)
  ax.plot(t,y,label='{}Hz'.format(f))
plt.legend
from google.colab import drive
drive.mount('/drive')
plt.savefig('/drive/My Drive/toancc/basic.python.pdf')
plt.show()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# main figure
axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('title')

# insert
axes2.plot(y, x, 'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('insert title');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0a6b97af6c0d> in <module>()
#       6
#       7 # main figure
# ----> 8 axes1.plot(x, y, 'r')
#       9 axes1.set_xlabel('x')
#      10 axes1.set_ylabel('y')
#
# NameError: name 'x' is not defined

# %%
def thue(phan_tram):return lambda x:x* phan_tram
hcm= thue(0.2)

# %%
hinhthang = lambda f,a,b:(b-a)*(f(a)+f(b))/2
from math import exp
hinhthang(exp,0,1)
